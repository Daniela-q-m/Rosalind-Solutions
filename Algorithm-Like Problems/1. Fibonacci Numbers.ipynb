# %%
Given: A positive integer n≤25.

Return: The value of Fn.

# %%
Fib_list=[0,1]
for i in range (1,100):
    Fib=Fib_list[i]+Fib_list[i-1]
    Fib_list.append(Fib)
print(Fib_list[22])
# Out:
# 17711
